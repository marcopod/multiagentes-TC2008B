# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import gymnasium as gym
from gymnasium import spaces

# %%
# stupid shit inverts them
COLUMNS = 10
ROWS = 2

# %%
class GridEnv(gym.Env):
    def __init__(self):
        super(GridEnv, self).__init__()
        self.action_space = spaces.Discrete(4)  # Up, Down, Left, Right
        self.observation_space = spaces.Box(low=0, high=np.array([COLUMNS-1, ROWS-1]), dtype=np.int32)
        self.reward_map = None
        self.step_counter = 0
        self.total_rewards_collected = 0
        self.reset()

    def reset(self):
        self.state = np.array([0, 0])  # Starting at top-left corner
        self.initialize_reward_map()
        self.step_counter = 0
        self.total_rewards_collected = 0
        return self.state

    def initialize_reward_map(self):
        self.reward_map = np.full((COLUMNS, ROWS), -1)
        self.reward_map[COLUMNS-1, 0] = 100  # Initial goal
        
    def step(self, action):
        # Initialize done as False
        done = False
        reward = 0.
        # Action mappings (no changes here)
        action_mappings = {
            0: (-1, 0),  # Move up
            1: (1, 0),   # Move down
            # 2: (0, -1),  # Move left
            2: (0, 1)    # Move right
        }
        
        delta = action_mappings.get(action, (0, 0))
        new_state = np.array([self.state[0] + delta[0], self.state[1] + delta[1]])

        # Corrected boundary conditions
        if new_state[0] < 0 or new_state[0] >= COLUMNS or new_state[1] < 0 or new_state[1] >= ROWS:
            reward = -100
            done = True
        else:
            self.state = new_state
            self.step_counter += 1
            reward = self.calculate_reward()
            done = self.is_done()

        y = self.state[0]
        x = self.state[1]

        # Check if goal is reached and update the reward map
        # if y == COLUMNS-1 and x == 0 and self.total_rewards_collected == 0: 
            # print("Goal 1 reached")
            # self.total_rewards_collected += 1
            # self.reward_map[COLUMNS-1,1] = 100  # Set new goal
            # self.reward_map[y, x] = -1  # Update old goal position
        
        return self.state, reward, done, {}

        
    def calculate_reward(self):
        # Check if the agent has reached the bottom of the grid
        # if self.state[0] == self.grid_size - 1:
        #     return 100
        # print(f"Reward obtained: {self.reward_map[self.state[0], self.state[1]]}")
        return self.reward_map[self.state[0], self.state[1]] 

    def is_done(self):
        # Check if all cells in the grid have been visited or if a step limit is reached
        max_steps = 100  # Example step limit
        return np.all(self.reward_map == -1) or self.step_counter >= max_steps            
        
    def render(self, mode='human'):
        plt.figure(figsize=(10, 2))  # Adjust the figure size to fit the 2x10 grid
        plt.imshow(self.reward_map, cmap='viridis', origin='lower')
        plt.scatter(self.state[1], self.state[0], c='red', marker='o')  # Agent's position
        plt.title("Agent's movement in 2x10 Grid")
        plt.pause(0.1)      

def train_agent(env, agent, episodes):
    for episode in range(episodes):
        state = env.reset()
        done = False
        total_reward = 0

        while not done:
            action = agent.choose_action(state)
            next_state, reward, done, _ = env.step(action)
            agent.learn(state, action, reward, next_state)
            state = next_state
            total_reward += reward # Performance

        if (episode % 10 == 0):
            print(f"Episode {episode}: Total Reward: {total_reward}")

# %%
def train_agent(env, agent, episodes):
    for episode in range(episodes):
        state = env.reset()
        done = False
        total_reward = 0

        while not done:
            action = agent.choose_action(state)
            next_state, reward, done, _ = env.step(action)
            agent.learn(state, action, reward, next_state)
            state = next_state
            total_reward += reward # Performance

        if (episode % 10 == 0):
            print(f"Episode {episode}: Total Reward: {total_reward}")

# %%
class QLearningAgent:
    def __init__(self, env, learning_rate=0.2, discount_factor=0.9, epsilon=0.1, gasoline_capacity=1000, wheat_capacity=100):
        self.env = env
        self.gasoline = gasoline_capacity  # Initial gasoline level
        self.wheat = 0  # Initial wheat level
        self.gasoline_capacity = gasoline_capacity
        self.wheat_capacity = wheat_capacity

        self.learning_rate = learning_rate
        self.discount_factor = discount_factor
        self.epsilon = epsilon
        self.q_table = np.zeros((COLUMNS, ROWS, env.action_space.n))

    def choose_action(self, state):
        if np.random.uniform(0, 1) < self.epsilon:
            action = self.env.action_space.sample()  # Random action
        else:
            state_index = (state[0], state[1])
            action = np.argmax(self.q_table[state_index])
        return action
    
    def learn(self, state, action, reward, next_state):
        state_index = (state[0], state[1])
        next_state_index = (next_state[0], next_state[1])
        # Update rule for Q-learning
        best_next_action = np.argmax(self.q_table[next_state_index])
        td_target = reward + self.discount_factor * self.q_table[next_state_index][best_next_action]
        td_error = td_target - self.q_table[state_index][action]
        self.q_table[state_index][action] += self.learning_rate * td_error

    def train(self, episodes):
        for _ in range(episodes):
            state = self.env.reset()
            done = False
            while not done:
                action = self.choose_action(state)
                next_state, reward, done, _ = self.env.step(action)
                self.learn(state, action, reward, next_state)
                state = next_state

# %%
# Train the agent
env = GridEnv()
agent = QLearningAgent(env)
train_agent(env, agent, episodes=1000)
# Out:
# Episode 0: Total Reward: -100
# Episode 10: Total Reward: -138
# Episode 20: Total Reward: -182
# Episode 30: Total Reward: -108
# Episode 40: Total Reward: -118
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 50: Total Reward: -121
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 60: Total Reward: -103
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 70: Total Reward: -163
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 80: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 90: Total Reward: -122
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 100: Total Reward: 89
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 110: Total Reward: -120
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 120: Total Reward: 90
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 130: Total Reward: -109
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 140: Total Reward: -120
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 150: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 160: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 170: Total Reward: 89
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 180: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 190: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 200: Total Reward: -144
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 210: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 220: Total Reward: -105
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 230: Total Reward: 90
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 240: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 250: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 260: Total Reward: 91
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 270: Total Reward: 90
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 280: Total Reward: 91
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 290: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 300: Total Reward: -146
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 310: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 320: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 330: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 340: Total Reward: -151
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 350: Total Reward: -116
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 360: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 370: Total Reward: -100
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 380: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 390: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 400: Total Reward: -169
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 410: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 420: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 430: Total Reward: 90
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 440: Total Reward: 90
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 450: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 460: Total Reward: 91
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 470: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 480: Total Reward: -150
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 490: Total Reward: -144
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 500: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 510: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 520: Total Reward: 91
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 530: Total Reward: 90
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 540: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 550: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 560: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 570: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 580: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 590: Total Reward: -118
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 600: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 610: Total Reward: 90
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 620: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 630: Total Reward: 91
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 640: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 650: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 660: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 670: Total Reward: 90
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 680: Total Reward: 90
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 690: Total Reward: -111
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 700: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 710: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 720: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 730: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 740: Total Reward: 91
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 750: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 760: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 770: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 780: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 790: Total Reward: -109
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 800: Total Reward: -112
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 810: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 820: Total Reward: -107
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 830: Total Reward: 90
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 840: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 850: Total Reward: 91
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 860: Total Reward: 90
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 870: Total Reward: 90
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 880: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 890: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 900: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 910: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 920: Total Reward: -100
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 930: Total Reward: 90
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 940: Total Reward: -100
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 950: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 960: Total Reward: -172
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 970: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 980: Total Reward: -134
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Episode 990: Total Reward: 92
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached
# Goal 1 reached

# %%
def animation_plot(env, ax):
    ax.clear()
    ax.imshow(env.reward_map, cmap='viridis', alpha=0.8)
    ax.scatter(env.state[1], env.state[0], color='red', label='Agent', s=100)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.legend()

# print(env.reward_map)
def update(frame, env, agent, ax):
    if not hasattr(update, "done") or not update.done:
        action = agent.choose_action(env.state)
        _, _, update.done, _ = env.step(action)
        animation_plot(env, ax)

fig, ax = plt.subplots()

# Reset the environment for the animation
env.reset()

# Create the animation
animation = FuncAnimation(fig, lambda frame: update(frame, env, agent, ax), frames=100, interval=100)

# Display the animation in Jupyter Notebook
HTML(animation.to_jshtml())
# Out:
# Goal 1 reached
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgcc9d1649cfee4050ab6df180d61e5f98">
#   <div class="anim-controls">
#     <input id="_anim_slidercc9d1649cfee4050ab6df180d61e5f98" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animcc9d1649cfee4050ab6df180d61e5f98.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animcc9d1649cfee4050ab6df180d61e5f98.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animcc9d1649cfee4050ab6df180d61e5f98.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animcc9d1649cfee4050ab6df180d61e5f98.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animcc9d1649cfee4050ab6df180d61e5f98.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animcc9d1649cfee4050ab6df180d61e5f98.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animcc9d1649cfee4050ab6df180d61e5f98.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animcc9d1649cfee4050ab6df180d61e5f98.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animcc9d1649cfee4050ab6df180d61e5f98.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animcc9d1649cfee4050ab6df180d61e5f98.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectcc9d1649cfee4050ab6df180d61e5f98"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_cc9d1649cfee4050ab6df180d61e5f98"
#              >
#       <label for="_anim_radio1_cc9d1649cfee4050ab6df180d61e5f98">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_cc9d1649cfee4050ab6df180d61e5f98"
#              checked>
#       <label for="_anim_radio2_cc9d1649cfee4050ab6df180d61e5f98">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_cc9d1649cfee4050ab6df180d61e5f98"
#              >
#       <label for="_anim_radio3_cc9d1649cfee4050ab6df180d61e5f98">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgcc9d1649cfee4050ab6df180d61e5f98";
#     var slider_id = "_anim_slidercc9d1649cfee4050ab6df180d61e5f98";
#     var loop_select_id = "_anim_loop_selectcc9d1649cfee4050ab6df180d61e5f98";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjguMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8g+/7EAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAATvUlE

# %%
# def plot_q_values(agent):
#     fig, axs = plt.subplots(agent.env.grid_size, agent.env.grid_size, figsize=(20, 20))

#     # Iterate over all grid cells
#     for i in range(agent.env.grid_size):
#         for j in range(agent.env.grid_size):
#             ax = axs[i, j]
#             q_values = agent.q_table[i, j]

#             # Use a bar chart or similar to represent Q-values for each action
#             ax.bar(range(len(q_values)), q_values, color=['blue', 'green', 'red', 'purple'])
#             ax.set_ylim([-100, 100])  # Assuming Q-values are in this range; adjust as needed
#             ax.set_xticks(range(len(q_values)))
#             ax.set_xticklabels(['Up', 'Down', 'Left', 'Right'])
#             ax.set_title(f"State ({i}, {j})")

#     plt.tight_layout()
#     plt.show()

# # Assuming your agent is named 'agent' and has been trained
# plot_q_values(agent)
